# %% [markdown]
# # imports

# %%
import pandas as pd
import os

# %% [markdown]
# # read data

# %% [markdown]
# ## view crimes and save crimes and files in a dict

# %%
crimes = os.listdir('police_data')
crimes.remove('tree_file.txt')
crime_files = {i:os.listdir(os.path.join('police_data',i)) for i in crimes}
crimes
# Out:
# ['abigeato',
#  'amenazas',
#  'delitos_sexuales',
#  'extorsion',
#  'homicidios',
#  'homicidios_accidente_de_transito',
#  'hurto_a_comercio',
#  'hurto_a_entidades_financieras',
#  'hurto_a_personas',
#  'hurto_a_residencias',
#  'hurto_motocicletas',
#  'hurto_vehiculos',
#  'lesiones_en_accidente_de_transito',
#  'lesiones_personales',
#  'pirateria_terrestre',
#  'secuestro',
#  'terrorismo',
#  'violencia_intrafamiliar']

# %% [markdown]
# ## function for trans

# %%
#for the dane code
def clean_cod_dane(cod):
    if len(cod) == 7:
        return '0'+ cod
    else:
        return cod

    
#only read for column names    
def read_dataset(path):
    df = pd.read_excel(path,nrows=30)
    
    #get first element
    first_reg = [str(n).upper() for n in list(df.iloc[:20,0])].index('DEPARTAMENTO')
    
    df = pd.read_excel(path, 
                   skiprows=first_reg+1, #ignore header
                    nrows=30,
                   dtype={'CODIGO DANE':str}#,'CANTIDAD':int}
                  )
    
    # rename cols
    df.columns = [n.upper().replace('*','').replace(' ','_') for n in df.columns]
    
    return df


#read and transform
def read_n_transform_dataset(path):
    df = pd.read_excel(path,nrows=30)
    
    #get first element
    first_reg = [str(n).upper() for n in list(df.iloc[:20,0])].index('DEPARTAMENTO')
    
    df = pd.read_excel(path, 
                   skiprows=first_reg+1, #ignore header
                   dtype={'CODIGO DANE':str,'DEPARTAMENTO':str}#,'CANTIDAD':int}
                  )
    
    # rename cols
    df.columns = [n.upper()\
                  .replace('*','')\
                  .replace(' ','_')\
                  .replace('AGRUPA_EDAD_PERSONA','GRUPO_ETARIO') for n in df.columns]
    
    #drop last info
    last_reg = [str(i).strip() for i in list(df.DEPARTAMENTO)].index('TOTAL')
    df = df.iloc[:last_reg,:]
    
    #correct DANE code
    df['CODIGO_DANE'] = df['CODIGO_DANE'].apply(lambda x: clean_cod_dane(str(x)))
    df['CANTIDAD'] = df['CANTIDAD'].apply(lambda x: int(x))
    return df

# %% [markdown]
# ## review the columns

# %%
for crime,files in crime_files.items():
#     _df = read_dataset(os.path.join('police_data',k,v[0]))
    for file in files:
        _df = read_dataset(os.path.join('police_data',crime,file))
        print(crime+' '+file+' : ')
        print(_df.columns)
    print('\n')
# Out:
# abigeato 2010.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# abigeato 2011.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# abigeato 2012.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# abigeato 2013.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# abigeato 2014.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# abigeato 2015.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# abigeato 2016.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# abigeato 2017.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# abigeato 2018.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# abigeato 2019.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# abigeato 2020.xls :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
#
#
# amenazas 2010.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# amenazas 2011.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# amenazas 2012.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# amenazas 2013.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# amenazas 2014.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# amenazas 2015.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# amenazas 2016.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# amenazas 2017.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# amenazas 2018.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# amenazas 2019.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# amenazas 2020.xls :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
#
#
# delitos_sexuales 2010.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# delitos_sexuales 2011.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# delitos_sexuales 2012.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# delitos_sexuales 2013.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# delitos_sexuales 2014.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# delitos_sexuales 2015.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# delitos_sexuales 2016.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# delitos_sexuales 2017.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# delitos_sexuales 2018.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# delitos_sexuales 2019.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# delitos_sexuales 2020.xls :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
#
#
# extorsion 2010.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# extorsion 2011.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# extorsion 2012.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# extorsion 2013.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# extorsion 2014.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# extorsion 2015.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# extorsion 2016.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD',
#        'UNNAMED:_8', 'UNNAMED:_9', 'UNNAMED:_10', 'UNNAMED:_11', 'UNNAMED:_12',
#        'UNNAMED:_13'],
#       dtype='object')
# extorsion 2017.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# extorsion 2018.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# extorsion 2019.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# extorsion 2020.xls :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
#
#
# homicidios 2010.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# homicidios 2011.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# homicidios 2012.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# homicidios 2013.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# homicidios 2014.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# homicidios 2015.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# homicidios 2016.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# homicidios 2017.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# homicidios 2018.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# homicidios 2019.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# homicidios 2020.xls :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
#
#
# homicidios_accidente_de_transito 2010.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'FECHA_HECHO', 'GENERO',
#        'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# homicidios_accidente_de_transito 2011.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'FECHA_HECHO', 'GENERO',
#        'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# homicidios_accidente_de_transito 2012.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'FECHA_HECHO', 'GENERO',
#        'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# homicidios_accidente_de_transito 2013.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'FECHA_HECHO', 'GENERO',
#        'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# homicidios_accidente_de_transito 2014.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'FECHA_HECHO', 'GENERO',
#        'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# homicidios_accidente_de_transito 2015.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'FECHA_HECHO', 'GENERO',
#        'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# homicidios_accidente_de_transito 2016.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'FECHA_HECHO', 'GENERO',
#        'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# homicidios_accidente_de_transito 2017.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'FECHA_HECHO', 'GENERO',
#        'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# homicidios_accidente_de_transito 2018.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'FECHA_HECHO', 'GENERO',
#        'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# homicidios_accidente_de_transito 2019.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'FECHA_HECHO', 'GENERO',
#        'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# homicidios_accidente_de_transito 2020.xls :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'FECHA_HECHO', 'GENERO',
#        'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
#
#
# hurto_a_comercio 2010.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_a_comercio 2011.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_a_comercio 2012.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_a_comercio 2013.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_a_comercio 2014.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_a_comercio 2015.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_a_comercio 2016.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_a_comercio 2017.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_a_comercio 2018.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_a_comercio 2019.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_a_comercio 2020.xls :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
#
#
# hurto_a_entidades_financieras 2010.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_a_entidades_financieras 2011.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_a_entidades_financieras 2012.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_a_entidades_financieras 2013.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_a_entidades_financieras 2014.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_a_entidades_financieras 2015.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_a_entidades_financieras 2016.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_a_entidades_financieras 2017.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_a_entidades_financieras 2018.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_a_entidades_financieras 2019.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_a_entidades_financieras 2020.xls :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
#
#
# hurto_a_personas 2010.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_a_personas 2011.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_a_personas 2012.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'GRUPO_ETARIO', 'CANTIDAD'],
#       dtype='object')
# hurto_a_personas 2013.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_a_personas 2014.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_a_personas 2015.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_a_personas 2016.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_a_personas 2017.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_a_personas 2018.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_a_personas 2019.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_a_personas 2020.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
#
#
# hurto_a_residencias 2010.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_a_residencias 2011.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_a_residencias 2012.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_a_residencias 2013.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_a_residencias 2014.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_a_residencias 2015.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_a_residencias 2016.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_a_residencias 2017.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_a_residencias 2018.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_a_residencias 2019.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_a_residencias 2020.xls :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
#
#
# hurto_motocicletas 2010.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_motocicletas 2011.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_motocicletas 2012.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_motocicletas 2013.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_motocicletas 2014.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_motocicletas 2015.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_motocicletas 2016.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_motocicletas 2017.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_motocicletas 2018.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_motocicletas 2019.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_motocicletas 2020.xls :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_motocicletas 2021.xls :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
#
#
# hurto_vehiculos 2010.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_vehiculos 2011.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_vehiculos 2012.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_vehiculos 2013.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_vehiculos 2014.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_vehiculos 2015.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_vehiculos 2016.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_vehiculos 2017.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_vehiculos 2018.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# hurto_vehiculos 2019.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# hurto_vehiculos 2020.xls :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
#
#
# lesiones_en_accidente_de_transito 2010.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'FECHA_HECHO', 'GENERO',
#        'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# lesiones_en_accidente_de_transito 2011.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'FECHA_HECHO', 'GENERO',
#        'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# lesiones_en_accidente_de_transito 2012.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'FECHA_HECHO', 'GENERO',
#        'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# lesiones_en_accidente_de_transito 2013.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'FECHA_HECHO', 'GENERO',
#        'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# lesiones_en_accidente_de_transito 2014.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'FECHA_HECHO', 'GENERO',
#        'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# lesiones_en_accidente_de_transito 2015.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'FECHA_HECHO', 'GENERO',
#        'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# lesiones_en_accidente_de_transito 2016.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'FECHA_HECHO', 'GENERO',
#        'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# lesiones_en_accidente_de_transito 2017.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# lesiones_en_accidente_de_transito 2018.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'FECHA_HECHO', 'GENERO',
#        'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# lesiones_en_accidente_de_transito 2019.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'FECHA_HECHO', 'GENERO',
#        'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# lesiones_en_accidente_de_transito 2020.xls :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'FECHA_HECHO', 'GENERO',
#        'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
#
#
# lesiones_personales 2010.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# lesiones_personales 2011.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# lesiones_personales 2012.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# lesiones_personales 2013.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# lesiones_personales 2014.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# lesiones_personales 2015.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# lesiones_personales 2016.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# lesiones_personales 2017.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# lesiones_personales 2018.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# lesiones_personales 2019.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# lesiones_personales 2020.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
#
#
# pirateria_terrestre 2010.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# pirateria_terrestre 2011.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# pirateria_terrestre 2012.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# pirateria_terrestre 2013.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# pirateria_terrestre 2014.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# pirateria_terrestre 2015.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# pirateria_terrestre 2016.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# pirateria_terrestre 2017.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# pirateria_terrestre 2018.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# pirateria_terrestre 2019.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# pirateria_terrestre 2020.xls :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
#
#
# secuestro 2010.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'DESCRIPCION_CONDUCTA',
#        'CANTIDAD'],
#       dtype='object')
# secuestro 2011.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'DESCRIPCION_CONDUCTA',
#        'CANTIDAD'],
#       dtype='object')
# secuestro 2012.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'DESCRIPCION_CONDUCTA',
#        'CANTIDAD'],
#       dtype='object')
# secuestro 2013.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'DESCRIPCION_CONDUCTA',
#        'CANTIDAD'],
#       dtype='object')
# secuestro 2014.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'DESCRIPCION_CONDUCTA',
#        'CANTIDAD'],
#       dtype='object')
# secuestro 2015.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'DESCRIPCION_CONDUCTA',
#        'CANTIDAD'],
#       dtype='object')
# secuestro 2016.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'DESCRIPCION_CONDUCTA',
#        'CANTIDAD'],
#       dtype='object')
# secuestro 2017.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'DESCRIPCION_CONDUCTA',
#        'CANTIDAD'],
#       dtype='object')
# secuestro 2018.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'DESCRIPCION_CONDUCTA',
#        'CANTIDAD'],
#       dtype='object')
# secuestro 2019.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'DESCRIPCION_CONDUCTA',
#        'CANTIDAD'],
#       dtype='object')
# secuestro 2020.xls :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
#
#
# terrorismo 2010.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# terrorismo 2011.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# terrorismo 2012.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# terrorismo 2013.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# terrorismo 2014.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# terrorismo 2015.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# terrorismo 2016.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# terrorismo 2017.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# terrorismo 2018.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# terrorismo 2019.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
# terrorismo 2020.xls :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'CANTIDAD'],
#       dtype='object')
#
#
# violencia_intrafamiliar 2010.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# violencia_intrafamiliar 2011.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# violencia_intrafamiliar 2012.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# violencia_intrafamiliar 2013.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# violencia_intrafamiliar 2014.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# violencia_intrafamiliar 2015.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# violencia_intrafamiliar 2016.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# violencia_intrafamiliar 2017.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# violencia_intrafamiliar 2018.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# violencia_intrafamiliar 2019.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')
# violencia_intrafamiliar 2020.xlsx :
# Index(['DEPARTAMENTO', 'MUNICIPIO', 'CODIGO_DANE', 'ARMAS_MEDIOS',
#        'FECHA_HECHO', 'GENERO', 'AGRUPA_EDAD_PERSONA', 'CANTIDAD'],
#       dtype='object')

# %% [markdown]
# ## read and transform

# %%
crime_dfs = {}
for crime,files in crime_files.items():
    df_list = []
    if crime in ['abigeato','amenazas']:
        continue
    for file in files:
        print(f'reading: {crime}/{file}')
        _df = read_n_transform_dataset(os.path.join('police_data',crime,file))
        print(f'{crime}/{file} succesfully read')
        df_list.append(_df)
    crime_dfs[crime] = pd.concat(df_list)
    crime_dfs[crime].to_csv(f'police_data/compilate_by_crime/{crime}.csv',index=False,encoding='utf8',sep=';')
    print(f'{crime} succesfully saved')
    print('\n')
# Out:
# reading: abigeato/2010.xlsx
# abigeato/2010.xlsx succesfully read
# reading: abigeato/2011.xlsx
# abigeato/2011.xlsx succesfully read
# reading: abigeato/2012.xlsx
# abigeato/2012.xlsx succesfully read
# reading: abigeato/2013.xlsx
# abigeato/2013.xlsx succesfully read
# reading: abigeato/2014.xlsx
# abigeato/2014.xlsx succesfully read
# reading: abigeato/2015.xlsx
# abigeato/2015.xlsx succesfully read
# reading: abigeato/2016.xlsx
# abigeato/2016.xlsx succesfully read
# reading: abigeato/2017.xlsx
# abigeato/2017.xlsx succesfully read
# reading: abigeato/2018.xlsx
# abigeato/2018.xlsx succesfully read
# reading: abigeato/2019.xlsx
# abigeato/2019.xlsx succesfully read
# reading: abigeato/2020.xls
# abigeato/2020.xls succesfully read
# abigeato succesfully saved
#
#
# reading: amenazas/2010.xlsx
# amenazas/2010.xlsx succesfully read
# reading: amenazas/2011.xlsx
# amenazas/2011.xlsx succesfully read
# reading: amenazas/2012.xlsx
# amenazas/2012.xlsx succesfully read
# reading: amenazas/2013.xlsx
# amenazas/2013.xlsx succesfully read
# reading: amenazas/2014.xlsx
# amenazas/2014.xlsx succesfully read
# reading: amenazas/2015.xlsx
# amenazas/2015.xlsx succesfully read
# reading: amenazas/2016.xlsx
# amenazas/2016.xlsx succesfully read
# reading: amenazas/2017.xlsx
# amenazas/2017.xlsx succesfully read
# reading: amenazas/2018.xlsx
# amenazas/2018.xlsx succesfully read
# reading: amenazas/2019.xlsx
# terrorismo/2018.xlsx succesfully read
# reading: terrorismo/2019.xlsx
# terrorismo/2019.xlsx succesfully read
# reading: terrorismo/2020.xls
# terrorismo/2020.xls succesfully read
# terrorismo succesfully saved
#
#
# reading: violencia_intrafamiliar/2010.xlsx
# violencia_intrafamiliar/2010.xlsx succesfully read
# reading: violencia_intrafamiliar/2011.xlsx
# violencia_intrafamiliar/2011.xlsx succesfully read
# reading: violencia_intrafamiliar/2012.xlsx
# violencia_intrafamiliar/2012.xlsx succesfully read
# reading: violencia_intrafamiliar/2013.xlsx
# violencia_intrafamiliar/2013.xlsx succesfully read
# reading: violencia_intrafamiliar/2014.xlsx
# violencia_intrafamiliar/2014.xlsx succesfully read
# reading: violencia_intrafamiliar/2015.xlsx
# violencia_intrafamiliar/2015.xlsx succesfully read
# reading: violencia_intrafamiliar/2016.xlsx
# violencia_intrafamiliar/2016.xlsx succesfully read
# reading: violencia_intrafamiliar/2017.xlsx
# violencia_intrafamiliar/2017.xlsx succesfully read
# reading: violencia_intrafamiliar/2018.xlsx
# violencia_intrafamiliar/2018.xlsx succesfully read
# reading: violencia_intrafamiliar/2019.xlsx
# violencia_intrafamiliar/2019.xlsx succesfully read
# reading: violencia_intrafamiliar/2020.xlsx
# violencia_intrafamiliar/2020.xlsx succesfully read
# violencia_intrafamiliar succesfully saved

# %% [markdown]
# ## review an error

# %%
for k,v in crime_dfs.items():
    
    if 'ESCOPOLAMINA' in list(v.CODIGO_DANE):
        print(k)
    else:
        continue
crime_dfs['hurto_a_comercio'][crime_dfs['hurto_a_comercio']['CODIGO_DANE'] == 'ESCOPOLAMINA'] 
the output was hurto_comercios in 2013
# Out:
# hurto_a_personas
# violencia_intrafamiliar

# %%
crime_dfs['hurto_a_comercio'][crime_dfs['hurto_a_comercio']['CODIGO_DANE'] == 'ESCOPOLAMINA']
# Out:
#        DEPARTAMENTO    MUNICIPIO  CODIGO_DANE         ARMAS_MEDIOS  \
# 250427       NARIÑO  NO REGISTRA  NO REGISTRA  SIN EMPLEO DE ARMAS
#
#        FECHA_HECHO    GENERO GRUPO_ETARIO  CANTIDAD
# 250427  2019-11-04  FEMENINO      ADULTOS         1

# %%
# se equivocaron en el hurto a comercios 2013
for crime,files in crime_files.items():
    df_list = []
    if crime != 'hurto_a_comercio':
        continue
    for file in files:
        print(f'reading: {crime}/{file}')
        _df = read_n_transform_dataset(os.path.join('police_data',crime,file))
        print(f'{crime}/{file} succesfully read')
        df_list.append(_df)
    crime_dfs[crime] = pd.concat(df_list)
    crime_dfs[crime].to_csv(f'police_data/compilate_by_crime/{crime}.csv',index=False,encoding='utf8',sep=';')
    print(f'{crime} succesfully saved')
    print('\n')
# Out:
# reading: hurto_a_comercio/2010.xlsx
# hurto_a_comercio/2010.xlsx succesfully read
# reading: hurto_a_comercio/2011.xlsx
# hurto_a_comercio/2011.xlsx succesfully read
# reading: hurto_a_comercio/2012.xlsx
# hurto_a_comercio/2012.xlsx succesfully read
# reading: hurto_a_comercio/2013.xlsx
# hurto_a_comercio/2013.xlsx succesfully read
# reading: hurto_a_comercio/2014.xlsx
# hurto_a_comercio/2014.xlsx succesfully read
# reading: hurto_a_comercio/2015.xlsx
# hurto_a_comercio/2015.xlsx succesfully read
# reading: hurto_a_comercio/2016.xlsx
# hurto_a_comercio/2016.xlsx succesfully read
# reading: hurto_a_comercio/2017.xlsx
# hurto_a_comercio/2017.xlsx succesfully read
# reading: hurto_a_comercio/2018.xlsx
# hurto_a_comercio/2018.xlsx succesfully read
# reading: hurto_a_comercio/2019.xlsx
# hurto_a_comercio/2019.xlsx succesfully read
# reading: hurto_a_comercio/2020.xls
# hurto_a_comercio/2020.xls succesfully read
# hurto_a_comercio succesfully saved

# %% [markdown]
# ## view 1

# %%
crime_dfs['abigeato']
# Out:
#       DEPARTAMENTO          MUNICIPIO CODIGO_DANE         ARMAS_MEDIOS  \
# 0            HUILA        CAMPOALEGRE    41132000         NO REPORTADO
# 1             META  SAN JUAN DE ARAMA    50683000         NO REPORTADO
# 2           BOYACÁ              BELÉN    15087000         NO REPORTADO
# 3         CASANARE               PORE    85263000         NO REPORTADO
# 4           CALDAS              NEIRA    17486000         NO REPORTADO
# ...            ...                ...         ...                  ...
# 2234         HUILA           PITALITO    41551000  SIN EMPLEO DE ARMAS
# 2235     ATLÁNTICO        SABANALARGA    08638000  SIN EMPLEO DE ARMAS
# 2236         SUCRE           EL ROBLE    70233000  SIN EMPLEO DE ARMAS
# 2237         CESAR          AGUACHICA    20011000        ARMA DE FUEGO
# 2238  CUNDINAMARCA              TAUSA    25793000  SIN EMPLEO DE ARMAS
#
#      FECHA_HECHO     GENERO GRUPO_ETARIO  CANTIDAD
# 0     2010-01-01   FEMENINO      ADULTOS         1
# 1     2010-01-01  MASCULINO      ADULTOS         1
# 2     2010-01-02   FEMENINO      ADULTOS         1
# 3     2010-01-02  MASCULINO      ADULTOS         1
# 4     2010-01-03  MASCULINO      ADULTOS         1
# ...          ...        ...          ...       ...
# 2234  2020-12-27  MASCULINO      ADULTOS         1
# 2235  2020-12-28  MASCULINO      ADULTOS         1
# 2236  2020-12-28  MASCULINO      ADULTOS         1
# 2237  2020-12-31  MASCULINO      ADULTOS         1
# 2238  2020-12-31  MASCULINO      ADULTOS         1
#
# [28144 rows x 8 columns]

# %%
crime_dfs['abigeato'].groupby(['DEPARTAMENTO','MUNICIPIO'])['CANTIDAD'].sum().reset_index().sort_values('CANTIDAD', ascending=False)
# Out:
#      DEPARTAMENTO           MUNICIPIO  CANTIDAD
# 682          META  VILLAVICENCIO (CT)       583
# 416         CESAR     VALLEDUPAR (CT)       490
# 358      CASANARE          YOPAL (CT)       384
# 432  CUNDINAMARCA    BOGOTÁ D.C. (CT)       352
# 946         VALLE           CALI (CT)       317
# ..            ...                 ...       ...
# 771       QUINDÍO          BUENAVISTA         1
# 194        BOYACÁ            BUSBANZÁ         1
# 309        CALDAS             MARMATO         1
# 302        CALDAS          BELALCÁZAR         1
# 617         HUILA         SANTA MARÍA         1
#
# [985 rows x 3 columns]

# %% [markdown]
# # Add the crime and Merge all

# %%
for crime,c_df in crime_dfs.items():
    c_df['CRIME'] = crime

# %%
full_df = pd.concat(crime_dfs.values())

# %%
full_df.head()
# Out:
#   DEPARTAMENTO          MUNICIPIO CODIGO_DANE  ARMAS_MEDIOS  \
# 0        HUILA        CAMPOALEGRE    41132000  NO REPORTADO
# 1         META  SAN JUAN DE ARAMA    50683000  NO REPORTADO
# 2       BOYACÁ              BELÉN    15087000  NO REPORTADO
# 3     CASANARE               PORE    85263000  NO REPORTADO
# 4       CALDAS              NEIRA    17486000  NO REPORTADO
#
#            FECHA_HECHO     GENERO GRUPO_ETARIO  CANTIDAD     CRIME  \
# 0  2010-01-01 00:00:00   FEMENINO      ADULTOS         1  abigeato
# 1  2010-01-01 00:00:00  MASCULINO      ADULTOS         1  abigeato
# 2  2010-01-02 00:00:00   FEMENINO      ADULTOS         1  abigeato
# 3  2010-01-02 00:00:00  MASCULINO      ADULTOS         1  abigeato
# 4  2010-01-03 00:00:00  MASCULINO      ADULTOS         1  abigeato
#
#   DESCRIPCION_CONDUCTA
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
full_df.dtypes
# Out:
# DEPARTAMENTO            object
# MUNICIPIO               object
# CODIGO_DANE             object
# ARMAS_MEDIOS            object
# FECHA_HECHO             object
# GENERO                  object
# GRUPO_ETARIO            object
# CANTIDAD                 int64
# CRIME                   object
# DESCRIPCION_CONDUCTA    object
# dtype: object

# %%
full_df.to_csv('police_data/all_data.csv',index=False,encoding='utf8',sep=';')

# %%
full_df.DESCRIPCION_CONDUCTA.unique()
# Out:
# array([nan, 'ARTÍCULO 169. SECUESTRO EXTORSIVO',
#        'ARTÍCULO 168. SECUESTRO SIMPLE'], dtype=object)

# %%
'2010-07-23 00:00:00'[:10]
# Out:
# '2010-07-23'

# %%
full_df.dtypes
# Out:
# DEPARTAMENTO            object
# MUNICIPIO               object
# CODIGO_DANE             object
# ARMAS_MEDIOS            object
# FECHA_HECHO             object
# GENERO                  object
# GRUPO_ETARIO            object
# CANTIDAD                 int64
# CRIME                   object
# DESCRIPCION_CONDUCTA    object
# FECHA                   object
# dtype: object

# %%
full_df['FECHA'] = full_df['FECHA_HECHO'].apply(lambda x: pd.to_datetime(str(x)[:10], format='%Y-%m-%d', errors='ignore'))

# %%
full_df.head()
# Out:
#   DEPARTAMENTO          MUNICIPIO CODIGO_DANE  ARMAS_MEDIOS  \
# 0        HUILA        CAMPOALEGRE    41132000  NO REPORTADO
# 1         META  SAN JUAN DE ARAMA    50683000  NO REPORTADO
# 2       BOYACÁ              BELÉN    15087000  NO REPORTADO
# 3     CASANARE               PORE    85263000  NO REPORTADO
# 4       CALDAS              NEIRA    17486000  NO REPORTADO
#
#            FECHA_HECHO     GENERO GRUPO_ETARIO  CANTIDAD     CRIME  \
# 0  2010-01-01 00:00:00   FEMENINO      ADULTOS         1  abigeato
# 1  2010-01-01 00:00:00  MASCULINO      ADULTOS         1  abigeato
# 2  2010-01-02 00:00:00   FEMENINO      ADULTOS         1  abigeato
# 3  2010-01-02 00:00:00  MASCULINO      ADULTOS         1  abigeato
# 4  2010-01-03 00:00:00  MASCULINO      ADULTOS         1  abigeato
#
#   DESCRIPCION_CONDUCTA                FECHA
# 0                  NaN  2010-01-01 00:00:00
# 1                  NaN  2010-01-01 00:00:00
# 2                  NaN  2010-01-02 00:00:00
# 3                  NaN  2010-01-02 00:00:00
# 4                  NaN  2010-01-03 00:00:00

# %%
full_df[full_df['CRIME'] == 'secuestro']
# Out:
#    DEPARTAMENTO      MUNICIPIO CODIGO_DANE                 ARMAS_MEDIOS  \
# 0     ANTIOQUIA       APARTADÓ    05045000  ARMA BLANCA / CORTOPUNZANTE
# 1     ANTIOQUIA          BELLO    05088000  ARMA BLANCA / CORTOPUNZANTE
# 2     ANTIOQUIA        BRICEÑO    05107000  ARMA BLANCA / CORTOPUNZANTE
# 3     ANTIOQUIA        CÁCERES    05120000  ARMA BLANCA / CORTOPUNZANTE
# 4     ANTIOQUIA    CAÑASGORDAS    05138000  ARMA BLANCA / CORTOPUNZANTE
# ..          ...            ...         ...                          ...
# 82        VALLE      CALI (CT)    76001000                ARMA DE FUEGO
# 83    ANTIOQUIA  MEDELLÍN (CT)    05001000          SIN EMPLEO DE ARMAS
# 84        VALLE      CALI (CT)    76001000          SIN EMPLEO DE ARMAS
# 85        CAUCA        TORIBIO    19821000                ARMA DE FUEGO
# 86        CESAR       PAILITAS    20517000          SIN EMPLEO DE ARMAS
#
#             FECHA_HECHO     GENERO GRUPO_ETARIO  CANTIDAD      CRIME  \
# 0   2010-07-23 00:00:00  MASCULINO      ADULTOS         1  secuestro
# 1   2010-03-04 00:00:00  MASCULINO      ADULTOS         1  secuestro
# 2   2010-01-05 00:00:00  MASCULINO      ADULTOS         1  secuestro
# 3   2010-08-23 00:00:00  MASCULINO      ADULTOS         1  secuestro
# 4   2010-05-05 00:00:00  MASCULINO      ADULTOS         2  secuestro
# ..                  ...        ...          ...       ...        ...
# 82  2020-11-28 00:00:00  MASCULINO      ADULTOS         1  secuestro
# 83  2020-12-03 00:00:00  MASCULINO      ADULTOS         1  secuestro
# 84  2020-12-04 00:00:00  MASCULINO      ADULTOS         1  secuestro
# 85  2020-12-05 00:00:00  MASCULINO      ADULTOS         1  secuestro
# 86  2020-12-14 00:00:00  MASCULINO      ADULTOS         1  secuestro
#
#                  DESCRIPCION_CONDUCTA
# 0   ARTÍCULO 169. SECUESTRO EXTORSIVO
# 1   ARTÍCULO 169. SECUESTRO EXTORSIVO
# 2   ARTÍCULO 169. SECUESTRO EXTORSIVO
# 3   ARTÍCULO 169. SECUESTRO EXTORSIVO
# 4   ARTÍCULO 169. SECUESTRO EXTORSIVO
# ..                                ...
# 82                                NaN
# 83                                NaN
# 84                                NaN
# 85                                NaN
# 86                                NaN
#
# [2200 rows x 10 columns]

# %% [markdown]
# # summaries

# %%
all_crimes = full_df.groupby(['DEPARTAMENTO','MUNICIPIO','CODIGO_DANE'])['CANTIDAD'].sum().reset_index().sort_values('CANTIDAD', ascending=False)
all_crimes
# Out:
#       DEPARTAMENTO          MUNICIPIO  CODIGO_DANE  CANTIDAD
# 493   CUNDINAMARCA   BOGOTÁ D.C. (CT)     11001000   1346081
# 1064         VALLE          CALI (CT)     76001000    414010
# 70       ANTIOQUIA      MEDELLÍN (CT)     05001000    376321
# 135      ATLÁNTICO  BARRANQUILLA (CT)     08001000    183681
# 904      SANTANDER   BUCARAMANGA (CT)     68001000    132584
# ...            ...                ...          ...       ...
# 372       CASANARE          LA SALINA     85136000        39
# 939      SANTANDER             JORDÁN     68370000        30
# 814    NO REGISTRA        NO REGISTRA  NO REGISTRA         3
# 748         NARIÑO                  -            -         3
# 789         NARIÑO        NO REGISTRA  NO REGISTRA         1
#
# [1105 rows x 4 columns]

# %%
all_crimes.to_csv('summaries/all_crimes.csv',index=False,encoding='utf8',sep=';')

# %%
by_crime = full_df.groupby(['DEPARTAMENTO','MUNICIPIO','CODIGO_DANE','CRIME'])['CANTIDAD'].sum().reset_index().sort_values('CANTIDAD', ascending=False)
by_crime
# Out:
#        DEPARTAMENTO         MUNICIPIO CODIGO_DANE                    CRIME  \
# 7186   CUNDINAMARCA  BOGOTÁ D.C. (CT)    11001000         hurto_a_personas
# 7195   CUNDINAMARCA  BOGOTÁ D.C. (CT)    11001000  violencia_intrafamiliar
# 7191   CUNDINAMARCA  BOGOTÁ D.C. (CT)    11001000      lesiones_personales
# 15550         VALLE         CALI (CT)    76001000         hurto_a_personas
# 1073      ANTIOQUIA     MEDELLÍN (CT)    05001000         hurto_a_personas
# ...             ...               ...         ...                      ...
# 8773        CÓRDOBA        BUENAVISTA    23079000      pirateria_terrestre
# 14546         SUCRE           SAMPUÉS    70670000                secuestro
# 13749     SANTANDER            LA PAZ    68397000       hurto_motocicletas
# 10339     MAGDALENA             PLATO    47555000                secuestro
# 7689   CUNDINAMARCA          GUATAQUÍ    25324000       hurto_motocicletas
#
#        CANTIDAD
# 7186     567788
# 7195     199840
# 7191     183680
# 15550    122658
# 1073     119947
# ...         ...
# 8773          1
# 14546         1
# 13749         1
# 10339         1
# 7689          1
#
# [16184 rows x 5 columns]

# %%
by_crime.to_csv('summaries/by_crime.csv',index=False,encoding='utf8',sep=';')

# %%
full_df['FECHA'] = pd.to_datetime(full_df['FECHA_HECHO'], format='%Y-%m-%d ', errors='ignore')

# %%
full_df.dtypes
# Out:
# DEPARTAMENTO            object
# MUNICIPIO               object
# CODIGO_DANE             object
# ARMAS_MEDIOS            object
# FECHA_HECHO             object
# GENERO                  object
# GRUPO_ETARIO            object
# CANTIDAD                 int64
# DESCRIPCION_CONDUCTA    object
# FECHA                   object
# dtype: object

# %%
full_df.head()
# Out:
#   DEPARTAMENTO          MUNICIPIO CODIGO_DANE  ARMAS_MEDIOS  \
# 0        HUILA        CAMPOALEGRE    41132000  NO REPORTADO
# 1         META  SAN JUAN DE ARAMA    50683000  NO REPORTADO
# 2       BOYACÁ              BELÉN    15087000  NO REPORTADO
# 3     CASANARE               PORE    85263000  NO REPORTADO
# 4       CALDAS              NEIRA    17486000  NO REPORTADO
#
#            FECHA_HECHO     GENERO GRUPO_ETARIO  CANTIDAD DESCRIPCION_CONDUCTA  \
# 0  2010-01-01 00:00:00   FEMENINO      ADULTOS         1                  NaN
# 1  2010-01-01 00:00:00  MASCULINO      ADULTOS         1                  NaN
# 2  2010-01-02 00:00:00   FEMENINO      ADULTOS         1                  NaN
# 3  2010-01-02 00:00:00  MASCULINO      ADULTOS         1                  NaN
# 4  2010-01-03 00:00:00  MASCULINO      ADULTOS         1                  NaN
#
#                  FECHA
# 0  2010-01-01 00:00:00
# 1  2010-01-01 00:00:00
# 2  2010-01-02 00:00:00
# 3  2010-01-02 00:00:00
# 4  2010-01-03 00:00:00

# %%
full_df.to_parquet('police_data/all_data.parquet')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_60/2004269832.py in <module>
# ----> 1 full_df.to_parquet('police_data/all_data.parquet')
#
# /opt/conda/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2675         from pandas.io.parquet import to_parquet
#    2676
# -> 2677         return to_parquet(
#    2678             self,
#    2679             path,
#
# /opt/conda/lib/python3.9/site-packages/pandas/io/parquet.py in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, **kwargs)
#     410     path_or_buf: FilePathOrBuffer = io.BytesIO() if path is None else path
#     411
# --> 412     impl.write(
#     413         df,
#     414         path_or_buf,
#
# /opt/conda/lib/python3.9/site-packages/pandas/io/parquet.py in write(self, df, path, compression, index, partition_cols, storage_options, **kwargs)
#     298
#     299         with catch_warnings(record=True):
# --> 300             self.api.write(
#     301                 path,
#     302                 df,
#
# /opt/conda/lib/python3.9/site-packages/fastparquet/writer.py in write(filename, data, row_group_offsets, compression, file_scheme, open_with, mkdirs, has_nulls, write_index, partition_on, fixed_text, append, object_encoding, times, custom_metadata)
#     857                        has_nulls)
#     858     ignore = partition_on if file_scheme != 'simple' else []
# --> 859     fmd = make_metadata(data, has_nulls=has_nulls, ignore_columns=ignore,
#     860                         fixed_text=fixed_text, object_encoding=object_encoding,
#     861                         times=times, index_cols=index_cols,
#
# /opt/conda/lib/python3.9/site-packages/fastparquet/writer.py in make_metadata(data, has_nulls, ignore_columns, fixed_text, object_encoding, times, index_cols, partition_cols)
#     674             se.name = column
#     675         else:
# --> 676             se, type = find_type(data[column], fixed_text=fixed,
#     677                                  object_encoding=oencoding, times=times)
#     678         col_has_nulls = has_nulls
#
# /opt/conda/lib/python3.9/site-packages/fastparquet/writer.py in find_type(data, fixed_text, object_encoding, times)
#     110     elif dtype == "O":
#     111         if object_encoding == 'infer':
# --> 112             object_encoding = infer_object_encoding(data)
#     113
#     114         if object_encoding == 'utf8':
#
# /opt/conda/lib/python3.9/site-packages/fastparquet/writer.py in infer_object_encoding(data)
#     298         return 'float'
#     299     else:
# --> 300         raise ValueError("Can't infer object conversion type: %s" % head)
#     301
#     302
#
# ValueError: Can't infer object conversion type: 0    2010-01-01 00:00:00
# 1    2010-01-01 00:00:00
# 2    2010-01-02 00:00:00
# 3    2010-01-02 00:00:00
# 4    2010-01-03 00:00:00
# 5    2010-01-03 00:00:00
# 6    2010-01-03 00:00:00
# 7    2010-01-04 00:00:00
# 8    2010-01-04 00:00:00
# 9    2010-01-04 00:00:00
# Name: FECHA_HECHO, dtype: object
